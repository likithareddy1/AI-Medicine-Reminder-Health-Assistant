# %% [markdown]
# ### Install packages

# %%
# !pip install SpeechRecognition pydub
# !pip install SpeechRecognition
# Out:
# Collecting SpeechRecognition
#   Downloading speechrecognition-3.17.0-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: pydub in /root/rocm/lib/python3.12/site-packages (0.25.1)
# Requirement already satisfied: typing-extensions in /root/rocm/lib/python3.12/site-packages (from SpeechRecognition) (4.15.0)
# Downloading speechrecognition-3.17.0-py3-none-any.whl (32.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 82.8 MB/s  0:00:00m0:00:0100:01
# Installing collected packages: SpeechRecognition
# Successfully installed SpeechRecognition-3.17.0
# Requirement already satisfied: SpeechRecognition in /root/rocm/lib/python3.12/site-packages (3.17.0)
# Requirement already satisfied: typing-extensions in /root/rocm/lib/python3.12/site-packages (from SpeechRecognition) (4.15.0)

# %%
# !pip uninstall click==8.4.0
# Out:
# Found existing installation: click 8.4.2
# Uninstalling click-8.4.2:
#   Would remove:
#     /root/rocm/lib/python3.12/site-packages/click-8.4.2.dist-info/*
#     /root/rocm/lib/python3.12/site-packages/click/*
# Proceed (Y/n)?

# %%
import speech_recognition as sr

recognizer = sr.Recognizer()

with sr.AudioFile("sample.wav") as source:
    audio = recognizer.record(source)

text = recognizer.recognize_google(audio)

print(text)

# %%
import speech_recognition as sr

# %%
recognizer = sr.Recognizer()

with sr.Microphone() as source:
    print("Speak now...")
    audio = recognizer.listen(source)

try:
    text = recognizer.recognize_google(audio)
    print("You said:", text)

except Exception as e:
    print(e)

# %%
query = text

result = assistant.graph.invoke({
    "messages": [query]
})

print(result["response"])
